# %% [markdown]
# # 10. Experiment Toolkits & Tips

# %% [markdown]
# ## 강의 소개
#
# - 마지막 강의로는 여러분들이 학습 과정을 로깅하는 방법과 툴 2가지를 소개해 드리겠습니다.
# - 그리고, 머신러닝 학습을 위한 방법 가운데서 Jupyter notebook과 Python IDLE 프로젝트가 어떤 장단점이 있는지 살펴보도록 하겠습니다.
# - 마지막으로, 제가 지금까지 머신러닝 공부를 하면서 느꼈던 여러가지 이야기를 전해드리려고 합니다.

# %% [markdown]
# <br>
#
# ## Further Reading
#
# -  Weight&Biases 홈페이지
#   - [https://wandb.ai/site](https://wandb.ai/site)
#   - 실험 관리 툴 wandb의 홈페이지 입니다. 해당 페이지에서 wandb에서 지정한 프로젝트의 결과를 확인할 수 있습니다.
# -  Paperswithcode
#   - [https://paperswithcode.com/](https://paperswithcode.com/)
#   - 최신 논문과 해당 논문의 코드를 확인할 수 있는 페이지 입니다.

# %% [markdown]
# <br>
#
# ## 10.1 Training Visualization
#
# - Tensorboard
# - Weight and Bias (wandb)

# %% [markdown]
# <br>
#
# ### 10.1.1 Tensorboard
#
# - 학습 과정을 기록하고 트래킹 하는 것도 중요하다.
#
# ```python
# from torch.utils.tensorboard import SummaryWriter
# logger = SummaryWriter(log_dir=f"results/{name}")
# ```
#
# ```python
# logger.add_scaler('Train/loss', train_loss, epoch * len(train_loader) + idx)
# logger.add_scaler('Train/accuracy', train_acc, epoch * len(train_loader) + idx)
# ```
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img src='https://drive.google.com/uc?id=1V8PFZAgaxZj1qdG67CafFAeWy6ffsy9L' width=600/>

# %% [markdown]
# <br>
#
# ```python
# for idx, train_batch in enumerate(train_loader):
#     inputs, labels = train_batch
#
#     ...
#
#     grid = torchvision.utils.make_grid(inputs)
#     logger.add_image('images', grid, 0)
#     logger.add_graph(model, inputs)
# ```
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img src='https://drive.google.com/uc?id=1mKeo_kd_8KxMW2Y-E_tzI6w60FFepeAS' width=600/>

# %% [markdown]
# <br>
#
# - 사용법
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img src='https://drive.google.com/uc?id=1pQQNhIDaB4BUHfn0dKIFJ5E7YOzdWiFk' width=600/>

# %% [markdown]
# <br>
#
# ### 10.1.2 Weight and Bias (wandb)
#
# - 딥러닝 로그의 깃허브 같은 느낌
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img src='https://drive.google.com/uc?id=1GBSJoV9Kh7lYuDgzjwBFWgaRyfLglUnB' width=800/>
#
# - 출처: https://wandb.ai/site

# %% [markdown]
# <br>
#
# #### 10.1.2.1 wandb login
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img src='https://drive.google.com/uc?id=1F3nU0ARhHwBbeft3pdAMiQJywKaBj-uy' width=800/>

# %% [markdown]
# <br>
#
# #### 10.1.2.2 wandb init, log 설정
#
# ```python
# import wandb
#
# # -- wandb initialize with configuration
# wandb.init(config={
#     'batch_size': batch_size,
#     'lr': lr,
#     'epochs': num_epochs,
#     'backborn': name
# })
# ```
#
# ```python
# # logging wandb train phase
# wandb.log({
#     'Train loss': train_loss,
#     'Train acc': train_acc
# })
# ```
#
# ```python
# # logging wandb valid phase
# wandb.log({
#     'Valid loss': val_loss,
#     'Valid acc': val_acc
# })
# ```

# %% [markdown]
# <br>
#
# #### 10.1.2.3 페이지에서 로그 확인
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img src='https://drive.google.com/uc?id=1eNeMyPihoMaCJfOTL3BNkakLjuXvuGl7' width=800/>

# %% [markdown]
# <br>
#
# ## 10.2 Machine Learning Project
#
# - Jupyter Notebook
# - Python IDLE

# %% [markdown]
# <br>
#
# ### 10.2.1 Jupyter Notebook
#
# - 코드를 아주 빠르게 Cell 단위로 실행해볼 수 있는 것이 장점
# - 보통 EDA 를 할 때 사용하면 매우 편리하다.
# - 학습 진행 도중 노트북 창이 꺼지면? $\rightarrow$ 못 돌아감

# %% [markdown]
# <br>
#
# ### 10.2.2 Python IDLE
#
# - 구현은 한번만
# - 사용은 언제든
# - 간편한 코드 재사용
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img src='https://drive.google.com/uc?id=13fMDvJtNIbRSTdUibX67JSWrz0Jsg3Oz' width=300/>
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img src='https://drive.google.com/uc?id=1IcZ0vq_9bMNzqRsB13eHPI_Yj4x-IzU9' width=600/>

# %% [markdown]
# - 사용할 줄 알면, 어떤 코드도 무섭지 않게 된다는 "디버깅"
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img src='https://drive.google.com/uc?id=1V4IO6psQPeAozlrtnGe0C-pMlwgivgup' width=800/>

# %% [markdown]
# - 자유로운 실험 핸들링
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img src='https://drive.google.com/uc?id=1pjMBNPWuEytBBSf6hcYE77Mx7KC6ba8R' width=800/>

# %% [markdown]
# <br>
#
# ## 10.3 Some Tips

# %% [markdown]
# ### 10.3.1 분석 코드 보다는 설명글을 유심히 보세요
#
# - 필자가 생각하고 있는 흐름을 읽을 수 있습니다.
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img src='https://drive.google.com/uc?id=1nqwY1W9WGuxGlTuvKaDS3C7L0iEOEGCB' width=600/>
#
# - 출처: https://www.kaggle.com/ash316/eda-to-prediction-dietanic

# %% [markdown]
# <br>
#
# ### 10.3.2 코드를 볼 때는 디테일한 부분까지
#
# - 언제든 활용할 수 있을 정도로..
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img src='https://drive.google.com/uc?id=1MomzBAHoPvIfuwkQmLeGHkE3YSpUsWWX' width=800/>

# %% [markdown]
# <br>
#
# ### 10.3.3 Paper with Codes
#
# - 최신 논문과 그 코드까지
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img src='https://drive.google.com/uc?id=1_bQJKdCilfH9y7J3x1UYaotLbzhnGH4Q' width=800/>
#
# - 출처: https://paperswithcode.com/

# %% [markdown]
# <br>
#
# ### 10.3.4 공유하는 것을 주저하지 마세요
#
# - 새로운 배움의 기회가 될 수 있습니다.
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img src='https://drive.google.com/uc?id=1a6Ci-KX_Au3RQSt6KcaXtZ6LNcSn5noU' width=800/>
