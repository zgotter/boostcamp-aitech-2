# %% [markdown]
# # 3. Dataset
#
# > Vanilla 데이터를 가지고 Dataset을 구성한 다음 모델에 빠르고, 효율적으로 Feeding 하기 위해 알아야 할 것들에 대해서 다룹니다.
# 강의에서 Data Feeding이라고 말하는 것의 개념과, 실제로 이것을 제대로 하지 않았을 때 어떤 일들이 일어날 수 있는지 알아보겠습니다.
#
# > 그리고, 파이토치에서 `torch.utils.data`에 있는 `Dataset`, `DataLoader`에 대한 설명과, 그 차이를 다뤄보겠습니다.

# %% [markdown]
# <br>
#
# ## 3.1 Overview
#
# - 주어진 Vanilla Data 를 모델이 좋아하는 형태의 Dataset 으로
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img src='https://drive.google.com/uc?id=13goSciSaS1NrUSet2y_oa-03hHkrvbhI' width=600/>
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img src='https://drive.google.com/uc?id=14taffXshsQHBX5vg2YjgOUXqsa-m4qqQ' width=800/>

# %% [markdown]
# <br>
#
# ## 3.2 Pre-processing

# %% [markdown]
# ### 3.2.1 Data Science is
#
# - pre-processing 이 대부분의 업무를 차지한다.
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img src='https://drive.google.com/uc?id=1XqA_wf385jzyF2hlPB3plLY_TGkkCYiF' width=600/>

# %% [markdown]
# <br>
#
# ### 3.2.2 Competition Data
#
# - 보통 경진대회용 데이터는 그 품질이 매우 양호한 편이다.
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img src='https://drive.google.com/uc?id=12iaabR_dYn4uX7S_olU7LtgsFidX4mzh' width=600/>

# %% [markdown]
# <br>
#
# ### 3.2.3 Bounding box
#
# - 가끔 필요 이상으로 많은 정보를 가지고 있기도 한다.
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img src='https://drive.google.com/uc?id=19mRBvZjMETioay_HnEDJ7qysvq1KblMY' width=800/>
#
# - 출처: https://www.kaggle.com/fulrose/3rd-ml-month-car-model-classification-baseline

# %% [markdown]
# <br>
#
# ### 3.2.4 Resize
#
# - 계산의 효율을 위해 적당한 크기로 사이즈 변경
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img src='https://drive.google.com/uc?id=1J24cKoITt5veq48APJxHpiaHQ9InIxEa' width=800/>

# %% [markdown]
# <br>
#
# ### 3.2.5 Example: APTOS Blindness Detection
#
# - 도메인, 데이터 형식에 따라 정말 다양한 Case가 존재
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img src='https://drive.google.com/uc?id=1cmvVfaWDOC44tJWSAEBfnAsXq4cd4qTv' width=800/>
#
# - 출처: https://www.kaggle.com/ratthachat/aptos-eye-preprocessing-in-diabetic-retinopathy

# %% [markdown]
# <br>
#
# ## 3.3 Generalization
#
# - 데이터셋에 대한 일반화

# %% [markdown]
# ### 3.3.1 Bias & Variance
#
# - 학습이 너무 안 됐거나, 학습이 너무 됐거나
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img src='https://drive.google.com/uc?id=1f99_KUFRgWfVgWwd2LURQ6tACjY6a7uY' width=600/>

# %% [markdown]
# <br>
#
# ### 3.3.2 Train / Validation
#
# - 훈련 셋 중 일정 부분을 따로 분리, 검증 셋으로 활용
# - 데이터가 줄어들긴 하지만 이렇게 하지 않으면 일반화가 잘 됐는 지를 판단할 수 없다.
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img src='https://drive.google.com/uc?id=1rnrrSH4025cQ75_dbfaswnm8Q5HTxFnC' width=600/>

# %% [markdown]
# <br>
#
# ### 3.3.3 Data Augmentation
#
# - 주어진 데이터가 가질 수 있는 case(경우), state(상태)의 다양성
# - 실제 문제에서는 아래와 같은 노이즈가 발생한 데이터가 들어올 수 있다.
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img src='https://drive.google.com/uc?id=1dgKSLgeWWVWtbsT3C7qeUqkdj78AS9FL' width=600/>
#
# - 문제가 만들어진 배경과 모델의 쓰임새를 살펴보면 힌트를 얻을 수 있다.

# %% [markdown]
# <br>
#
# ### 3.3.4 `torchvision.transforms`
#
# - 해당 라이브러리를 사용하여 augmentation 을 할 수 있다.
# - Image에 적용할 수 있는 다양한 함수들
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img src='https://drive.google.com/uc?id=1b3twNrc2ruEmN3jgGQe1AXk5KaMVdJPq' width=600/>
#
# - Flip 과 같이 사진을 찍었을 때 뒤집히는 경우가 실제로 있을 까?
#   - 굳이 안해도 되는 데이터가 될 수 있다.
# - data augmentation 을 할 때 이게 실제로 유용할 것인 지를 잘 생각하고 해야 한다.

# %% [markdown]
# - 종류는 많고, 사용은 간편하다.
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img src='https://drive.google.com/uc?id=1LbFL-drLdO135XVOAx_emD-8_nSAxSMx' width=800/>
#
# - `transforms.Compose()` : transforms 를 묶어주는 함수

# %% [markdown]
# <br>
#
# ### 3.3.5 Albumentations
#
# - 파이토치 패키지는 아니다.
# - 더 빠르고, 더 다양하다.
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img src='https://drive.google.com/uc?id=1HTr6A6pSNiHw68fhtsYbIF4kRhVIwc1a' width=900/>
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img src='https://drive.google.com/uc?id=1mBr0e5aggE79sts_t-iABtX4Xr5skIcR' width=600/>
#
# - 출처: https://github.com/albumentations-team/albumentations#benchmarking-results

# %% [markdown]
# <br>
#
# ### 3.3.6 "무조건" 이라는 단어를 조심
#
# - 항상 좋은 결과를 가져다 주지는 않는다.
# - 이러한 함수들은 여러 가지 **도구** 가운데 하나일 뿐이다.
# - 그리고, 무조건 적용 가능한 **마스터키 같은 것도 사실 없다.**
# - **앞서 정의한 Problem(주제)**을 깊이 관찰해서 어떤 기법을 적용하면 이러이러한 다양성을 가질 수 있겠다 가정하고 <font color='skyblue'>실험으로 증명해야 한다.</font>
