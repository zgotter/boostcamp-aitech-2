# %% [markdown]
# # 7. 데이터 구축 가이드라인 작성 기초

# %% [markdown]
# ## 강의 소개
#
# - 데이터 구축 프로세스를 조망하고, 가이드라인이 차지하는 위치에 대해 공부합니다.
# - 자연어처리 데이터 구축 가이드라인들의 예시를 알아봅니다.
# - 가이드라인 작성 도구들에 대해 알아봅니다.

# %% [markdown]
# <br>
#
# ## Further Reading
#
# - [Annotation Guideline for ABSA SemEval 2016-5](https://alt.qcri.org/semeval2016/task5/data/uploads/absa2016_annotationguidelines.pdf) [Paper]
# - [한국어 학습자 말뭉치 구어 전사 지침 (일부)](https://www.korean.go.kr/common/download.do;front=6D77D8BF0BE7B31D106B9CF1271E84F8?file_path=reportData&c_file_name=77dc5f04-c855-440b-8139-1bf7548d7e3a_0.pdf&o_file_name=2017%EB%85%84%20%ED%95%9C%EA%B5%AD%EC%96%B4%20%ED%95%99%EC%8A%B5%EC%9E%90%20%EB%A7%90%EB%AD%89%EC%B9%98%20%EC%97%B0%EA%B5%AC%20%EB%B0%8F%20%EA%B5%AC%EC%B6%95%20%EC%82%AC%EC%97%85.pdf) [Book]

# %% [markdown]
# <br>
#
# ## Further Questions
#
# - 전문가를 위한 가이드라인과 크라우드소싱에 활용되는 가이드라인은 어떤 차이가 있을까요?
# - 크라우드소싱에 참여하는 주석자들의 배경(e.g., 연령, 전공 등)이 상이할 경우 가이드라인 작성에 있어 예상되는 어려움은 무엇이 있나요?

# %% [markdown]
# <br>
#
# ## 7.1 가이드라인의 유형

# %% [markdown]
# ### 7.1.1 목적에 따른 분류
#
# - **수집**을 위한 가이드라인
# - **주석**을 위한 가이드라인
#   - 다른 작업자들이 수행하므로 가이드라인이 필수이다.
# - **검수**를 위한 가이드라인

# %% [markdown]
# <br>
#
# ### 7.1.2 제시 방식에 따른 분류
#
# - 문서형
# - 화면 노출형
# - 튜토리얼형

# %% [markdown]
# <br>
#
# ### 7.1.3 문서형 가이드라인 예시
#
# - 한국어 학습자 말뭉치 구축 가이드라인
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img src='https://drive.google.com/uc?id=1-7g8aTEzVMY4VMPZkb3eyOkC_RU_b8iM' width=800/>

# %% [markdown]
# <br>
#
# ### 7.1.4 튜토리얼 가이드라인 예시
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img src='https://drive.google.com/uc?id=1-9_9EwFKUEZP_CHbDXRMaX3EEcmYpeRK' width=800/>
#
# - [https://www.cashmission.com/cashmission_guide/53](https://www.cashmission.com/cashmission_guide/53)

# %% [markdown]
# <br>
#
# ## 7.2 가이드라인의 구성 요소

# %% [markdown]
# ### 7.2.1 구성 요소
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img src='https://drive.google.com/uc?id=1-AZzo7wo6qDdmJRGoplCROeJW-rGc42m' width=800/>

# %% [markdown]
# <br>
#
# ### 7.2.2 데이터 구축 목적 정의 예시
#
# - 작업자들의 작업에 대한 이해도를 높여 더 높은 품질의 데이터를 만들 수 있도록 돕는 역할
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img src='https://drive.google.com/uc?id=1-K4K_AccRw4j07sCGnAdnPGK-0xv7qE5' width=400/>
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img src='https://drive.google.com/uc?id=1-Td_QDPBlxylAMn_tEUOL3kLCVW-VEIX' width=400/>
#
# - [『인공지능 (AI) 학습용 데이터 품질관리 가이드라인 (v.1.0)』, 한국지능정보사회진흥원](http://knconsulting.co.kr/knowledge/?q=YToyOntzOjQ6InBhZ2UiO2k6MTtzOjEyOiJrZXl3b3JkX3R5cGUiO3M6MzoiYWxsIjt9&bmode=view&idx=6009133&t=board&category=bgG58851V4)
# - [『인공지능 (AI) 학습용 데이터셋 구축 안내서』, 한국지능정보사회진흥원](http://knconsulting.co.kr/knowledge/?q=YToyOntzOjQ6InBhZ2UiO2k6MTtzOjEyOiJrZXl3b3JkX3R5cGUiO3M6MzoiYWxsIjt9&bmode=view&idx=6009133&t=board&category=bgG58851V4)

# %% [markdown]
# <br>
#
# ### 7.2.3 데이터 구축 가이드라인 용어 정의 예시
#
# - annotation guidelines
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img src='https://drive.google.com/uc?id=1-V6VgB7qGc2dK33v8r8jdP85BS5eyxxL' width=800/>
#
# - [https://alt.qcri.org/semeval2016/task5/data/uploads/absa2016_annotationguidelines.pdf](https://alt.qcri.org/semeval2016/task5/data/uploads/absa2016_annotationguidelines.pdf)

# %% [markdown]
# <br>
#
# ### 7.2.4 데이터 수집 가이드라인 예시
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img src='https://drive.google.com/uc?id=1-jhVrQsMym05xZES5T0e7ZgOMLERXZuW' width=800/>
#
# - [https://kcorpus.korean.go.kr/boardFileDownload.data?seq=63](https://kcorpus.korean.go.kr/boardFileDownload.data?seq=63)

# %% [markdown]
# <br>
#
# ### 7.2.5 데이터 체계 제시 예시
#
# - 무엇을 어떻게 주석을 달아야 하는 지를 제시해줘야 한다.
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img src='https://drive.google.com/uc?id=1-a6Al-ILH8eI2VF5WwWXpksAB24YLWwZ' width=800/>
#
# - [https://kcorpus.korean.go.kr/boardFileDownload.data?seq=63](https://kcorpus.korean.go.kr/boardFileDownload.data?seq=63)
#
# <br>
#
# - 구문분석 말뭉치에 대한 데이터 체계 제시
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img src='https://drive.google.com/uc?id=1-eJJvmWWREmZqO1y725c5-oKIKavLS80' width=800/>
#
# - [https://www.cis.upenn.edu/~bies/manuals/tagguide.pdf](https://www.cis.upenn.edu/~bies/manuals/tagguide.pdf)

# %% [markdown]
# <br>
#
# ### 7.2.6 데이터 구축 도구 사용법 예시
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img src='https://drive.google.com/uc?id=1-gKMcFyhxn0HFEIH8nlm4y2cdfGC0yn5' width=800/>
#
# - [https://balsamiq.com/learn/articles/wireframe-annotations/](https://balsamiq.com/learn/articles/wireframe-annotations/)

# %% [markdown]
# <br>
#
# ## 7.3 가이드라인 버전 관리
#
# - 가이드라인은 구축과 검수 과정을 통해 지속적으로 개정되어야 함
# - 개정 전과 개정 후 어떤 것이 변화하였는지 비교하여 볼 수 있도록 버전 관리가 되는 것이 가장 좋음
# - 버전별로 작성자와 개정일을 기입해두는 것이 관리에 도움이 됨

# %% [markdown]
# <br>
#
# ## 7.4 가이드라인 작성 도구
#
# - Google Docs
# - Notion
# - 워드 및 한글
# - 그 외
#   - 레이블링 에이전시에서 제공하는 도구
#   - 위키

# %% [markdown]
# <br>
#
# ## 7.5 가이드라인 작성 시 유의 사항
#
# - 가이드라인의 유형별 특성을 이해하고 그에 알맞는 정보를 작성한다.
# - 작업자의 작업 이해도를 고려하여 작성한다.
# - 작업자에게 공개해야 하는 필수 정보와 부가적인 정보가 무엇인지 사전에 고려한다.
# - 가이드라인 구성 요소의 배치를 어떻게 할 지 고민한다.
# - 작업자의 **가독성**을 고려한다.
